# %%
import messenger_stats

import argparse
import os
import shutil

from datetime import datetime

from conversation_stats import conversationAnalyzer
from conversation_time_series import timeSeriesAnalyzer
from largest_chats import largestChatAnalyzer

# %%
def setupDirTree(folderDir, outputDir="./"):
    if not folderDir:
        if os.path.isdir('messages/inbox'):
            folderDir = 'messages/inbox'
        else:
            raise IOError((
                'Error: must specify path to messages directory or have '
                'the messages/inbox directory in current directory'
            ))

    # create output dirs, deleting old if exists
    if os.path.isdir(outputDir):
        shutil.rmtree(outputDir)
    aggreOutDir = os.path.join(outputDir, 'aggregate')
    timeOutDir = os.path.join(outputDir, 'timeSeries')
    timeGraphOutDir = os.path.join(outputDir, 'timeSeries', 'graphs')
    os.makedirs(aggreOutDir)
    os.makedirs(timeOutDir)
    os.makedirs(timeGraphOutDir)
    return folderDir, aggreOutDir, timeOutDir

# %%
parser = argparse.ArgumentParser()
parser.add_argument('-f', '--folder', help='root messages directory')
parser.add_argument('-d', '--startDate',
                    help='earliest message from this date (YYYY-MM-DD)')
parser.add_argument('-e', '--endDate',
                    help='last message up to this date (YYYY-MM-DD)')
parser.add_argument(
    '-m', '--minSize', help="size of smallest chat you wish to include", type=int, default=10000)
parser.add_argument(
    '-s', '--sortby', help="by what to sort the largest chats (messages, characters, both)", default="messages")
parser.add_argument(
    '-o', '--output', help="where to save the output data", default="./output")
parser.add_argument(
    '-n', '--topN', help="top N chats displayed per time interval", default=10, type=int)
parser.add_argument('-t', '--timeInterval',
                    help="number of days for each time interval", default=30, type=int)
parser.add_argument('-p', '--plotTimeInterval',
                    help="whether to plot individual plots for time series analysis", action='store_true')
parser.add_argument('--sender_name', help="name of the account owner")
args = parser.parse_args()

args.folder = "../../../Downloads/facebook-tongtianliu2/messages/inbox"
MIN_MESSAGE_COUNT = args.minSize
#args.startDate="2020-08-01"
startDate = None
if (args.startDate):
    startDate = datetime.strptime(args.startDate, "%Y-%m-%d")
endDate = None
if (args.endDate):
    endDate = datetime.strptime(args.endDate, "%Y-%m-%d")

folderDir, aggreOutDir, timeOutDir = setupDirTree(
    args.folder, outputDir=args.output)

basicAnalysis = True
if(basicAnalysis):
    largestChatAnalyzer(folderDir, MIN_MESSAGE_COUNT,
                        startDate=startDate, endDate=endDate, sortby=args.sortby, outputDir=aggreOutDir)

karmaAnalysis = False
if(karmaAnalysis):
    # conversationAnalyzer(folderDir, MIN_MESSAGE_COUNT,folderDir)
    pass

timeAnalysis = True
if (timeAnalysis):
    print(startDate, endDate)
    sender_name = args.sender_name
    timeSeriesAnalyzer(folderDir, MIN_MESSAGE_COUNT, sender_name,
                       startDate=startDate, endDate=endDate, outputDir=timeOutDir,
                       TOP_N_PER_INTERVAL=args.topN, TIME_INTERVAL=args.timeInterval, plot=args.plotTimeInterval)
# Out:
# finding largest chats
# making top conversation graph
# done aggregate
# None None
# time series
# duplicate: Allen et Isaac
# duplicate: Allen et Ramsey
# duplicate: Allen et Ramsey
# duplicate: Allen, Ramsey et Sydney
# duplicate: Andrew Wang
# duplicate: Chaereen et Jay
# duplicate: Edward Yang
# duplicate: Henry Zhu
# duplicate: Ivan, Josh, Gus et Rajiv
# duplicate: James et Andrew
# duplicate: Jay Hu
# duplicate: Jerry Zhang
# duplicate: Jesse, Eddie, Paul et 2 autres personnes
# duplicate: Kevin Zhang
# duplicate: Richard Chen
# duplicate: Richard et Grace
# duplicate: Robert DiBartolomeo
# duplicate: Tiffany Wang
# duplicate: Tom Â· Mattress
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Utilisateur Facebook
# duplicate: Yuan et Will
# plotting
# No handles with labels found to put in legend.
# done with Angie Hu
# done with Grace Cho
# done with Felix Weilacher
# done with gcc humans in boston
# done with Virtu
# done with Doris Lee
# done with Jason Han
# done with Moonshine Mtl
# done with Brighton + (Webster + Sutherland)Macrophages
# done with James Guo
# done with Yohan Sequeira
# done with what are you talking about
# done with Nicola Liu
# done with Josephine Yu
# done with Michael SungHun Hwang
# done with mathematica pals
# done with Allen He
# done with James Hu
# done with Yi Tang
# done with Thanksgiving Trip 2021
# done with Catan
# done with BadFish Prom Limo
# done with fuck Spanish 2k15
# done with Lisa Yang
# done with Michelle Yang
# done with Emrys Peets
# done with Nick Hagemann
# done with Toby Duro
# done with Jack Piotrowski
# done with Carrie Wang
# done with Robin Zhang
# done with Derp Dump
# done with seniors gone wild ***OFFICIAL*** planning committee
# done with Evan Zou
# done with SCIOLY Officers 2015
# done with Maokai
# done with Chandrika Sanapala
# done with Michelle Xu
# done with Caroline Cai
# done with Things high school never taught me about
# done with FBLA Brighton Nationals
# done with Sushant Koirala
# done with N O T T H I C C Earth Knwoedlege Socitey
# done with Wenwen Tang
# done with TSJK 420
# done with RAT
# done with Samuel Ip
# done with Adi Somasundaram
# done with Brighton Envirothon Winning Team
# done with cheese is a scam
# done with Jiyeux Seok
# done with Neverland Servants Team
# done with servant sneks
# done with Rafi Hessami
# done with Vocab Assistant
# done with Andrew Cui
# done with Yiyang Zhang
# done with Emma Simmerman
# done with Hannah Tiongson
# done with Evangel Young Adults
# done with Paradigm SHIFT servants
# done with Mike Sha
# done with Megan Foo
# done with flakers
# done with Rachel May
# done with fnce powergroup
# done with Eclipse Trip
# done with Chris Lo
# done with 520 Project
# done with henryzhu_ae8yz5y_tq
# done with GCC ðððð
# done with TBD
# done with Math team officers
# done with Calc Mentoring
# done with exp(x) = 1 + x
# done with Return of the JCC *REIGNING CHAMPIONS!!!*
# done with michelle's friends
# done with Will Yeung
# done with GCC BRoooooSsSs
# done with Grad Night!
# done with Angie Peng
# done with Corbin Corbin
# done with JooChan Shin
# done with Bill He
# done with Yuka Nakato
# done with the dance of death_accountability
# done with The Smash Brothers and Sisters
# done with GCC Bros
# done with Niggas in Paris
# done with Christopher Ye
# done with Joyce Xu
# done with weekly covid run
# done with Esther Jou
# done with Max Franklin
# done with bravest warriors
# done with Ramsey Reyes
# done with George Yang
# done with Gus Beane
# done with Shana Roan
# done with chess chess chess
# done with Christopher et Matthew
# done with Neverland FG
# done with FBLA "Nattys"
# done with The Return Of Party City
# done with GG EZ ap bio
# done with Pranav Devarakonda
# done with FBLA Officers
# done with cis bois at penn + tom
# done with Arvind Jared Vishak
# done with Ruth Lee
# done with Vivian Li
# done with Philly 2019 Summer
# done with snaks
# done with Ryan Kung
# done with Spring Break
# done with santander crew
# done with bill's dumb thoughts (would love others chiming in to our evergrowing perspectives)
# done with Programming
# done plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[2,3,4])
